# %% [markdown]
# <a href="https://colab.research.google.com/github/ernishantsharma4u-beep/deep-neural-assignment_1/blob/main/Linear_Regression_modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model

# %% [markdown]
# Load the CSv file

# %%
df = pd.read_excel("/content/Linear Regression _prob1.xlsx")
print(df)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %% [markdown]
# Plot the Graph

# %%
plt.xlabel('area')
plt.ylabel('price')

plt.scatter(df.area,df.price, color='red',marker = '+')

# %% [markdown]
# Define your Linear Model

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %% [markdown]
# do prediction

# %%
price = reg.predict(pd.DataFrame([3300]))
print( "the price is:",price)
# Out:
# the price is: [628715.75342466]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
m= reg.coef_
b= reg.intercept_
print("weight value is:",m)
print("intercept i.e. bias is:",b)
# Out:
# weight value is: [135.78767123]
# intercept i.e. bias is: 180616.43835616432

# %%
df = pd.read_excel("/content/Linear Regression _prob1.xlsx")
plt.xlabel('area',fontsize =20)
plt.ylabel('price',fontsize =20)
plt.scatter(df.area,df.price, color='blue',marker = '+')
plt.plot(df.area,reg.predict(df[['area']]),color='red')

# %%
d = pd.read_excel("/content/Area.xlsx")
d
# Out:
#      aea
# 0   5000
# 1   1200
# 2   1500
# 3   1000
# 4   1200
# 5   1250
# 6    850
# 7    750
# 8   6587
# 9   2258
# 10  1234
# 11  7895
# 12   654
# 13  1258
# 14  2255

# %% [markdown]
# Regression model to predict prices on data Area.xlsx by using function reg,predict with d as argument of it. this will return the predicted values

# %%
d.rename(columns={'aea': 'area'}, inplace=True)## use to avoid typo in name
p = reg.predict(d[['area']])
d['Prices'] = p
d
# Out:
#     area        Prices
# 0   5000  8.595548e+05
# 1   1200  3.435616e+05
# 2   1500  3.842979e+05
# 3   1000  3.164041e+05
# 4   1200  3.435616e+05
# 5   1250  3.503510e+05
# 6    850  2.960360e+05
# 7    750  2.824572e+05
# 8   6587  1.075050e+06
# 9   2258  4.872250e+05
# 10  1234  3.481784e+05
# 11  7895  1.252660e+06
# 12   654  2.694216e+05
# 13  1258  3.514373e+05
# 14  2255  4.868176e+05

# %% [markdown]
# adding Predicted data frame into Area excel file

# %%
d.to_excel('Area.xlsx')

# %% [markdown]
# To remove Indexing in Area excel file use Index = False

# %%
d.to_excel('Area.xlsx', index =False)
